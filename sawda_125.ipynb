# %%
 import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the histogram
plt.hist(random_numbers, bins=5,  alpha=0.5, color='blue', edgecolor='black')

# Labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Uniformly Distributed Random Numbers')
plt.grid(True)

# Show the plot
plt.show()

# %%
# Generate 500 random values from a normal distribution with mean=0 and std=1
NormalValues = np.random.normal(0, 1, 500)

# Create a histogram
plt.hist(NormalValues, bins=15, edgecolor='black')
plt.title('Histogram of Normal Distribution (mean=0, std=1)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# With fixed seed
np.random.seed(10)
seeded_matrix = np.random.randint(1, 51, (3, 3))
print("Seeded Random Matrix:\n", seeded_matrix)

# Without seed
np.random.seed(None)
non_seeded_matrix = np.random.randint(1, 51, (3, 3))
print("Non-Seeded Random Matrix:\n", non_seeded_matrix)
# Out:
# Seeded Random Matrix:
#  [[10 37 16]
#  [ 1 50 29]
#  [26 30 49]]
# Non-Seeded Random Matrix:
#  [[ 2 32  6]
#  [25 22 25]
#  [12  9 42]]

# %% [markdown]
# PART 1

# %%
import random  # to create random numbers

def estimate_pi(num_points):
    inside = 0  # how many points inside the circle

    for _ in range(num_points):
        x = random.uniform(0,3)  # pick a random number from 0 to 1
        y = random.uniform(0,3)
        if x*x + y*y <= 3*3:
            inside += 1  # it's inside the circle

    pi = 4* inside / num_points
    print("Estimated pi for", num_points, "points is:", pi)

# Try this with different number of points
estimate_pi(2000)
# Out:
# Estimated pi for 2000 points is: 3.228
